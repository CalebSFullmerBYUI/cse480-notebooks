# %% [markdown]
# # First let's import, then look for the assignment below

# %%
#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
import sys

# -- Detect if in Own Install or in Colab
try:
    import google.colab
    OWN_INSTALL = False
except:
    OWN_INSTALL = True
    
if OWN_INSTALL:
    
  sys.path[0:0] = ['../../../../..',  '../../../../../3rdparty',  
                   '../../../..',  '../../../../3rdparty',  
                   '../../..',     '../../../3rdparty', 
                   '../..',        '../../3rdparty',
                   '..',           '../3rdparty' ]

else: # In colab
  ! if [ ! -d Jove ]; then git clone https://github.com/ganeshutah/Jove Jove; fi
  sys.path.append('./Jove')
  sys.path.append('./Jove/jove')

# -- common imports --
from jove.LangDef   import *
#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Out:
# Cloning into 'Jove'...
# remote: Enumerating objects: 4634, done.
# remote: Total 4634 (delta 0), reused 0 (delta 0), pack-reused 4634
# Receiving objects: 100% (4634/4634), 7.38 MiB | 11.84 MiB/s, done.
# Resolving deltas: 100% (3005/3005), done.
# You may use any of these help commands:
# help(lphi)
# help(lunit)
# help(lcat)
# help(lexp)
# help(lunion)
# help(lstar)
# help(srev)
# help(lrev)
# help(shomo)
# help(lhomo)
# help(powset)
# help(lint)
# help(lsymdiff)
# help(lminus)
# help(lissubset)
# help(lissuperset)
# help(lcomplem)
# help(product)
# help(nthnumeric)

# %% [markdown]
# # Week 01 Notebook 2 on Python Basics

# %% [markdown]
# ## Define a regular language via Python's set builder (set comprehension) syntax
#
# <font size="4">
#
# Recall from Chapter-1 that sets of strings of the form "any number of $a$'s followed by any number of $b$'s followed by any number of $c$'s are regular languages.
#
# * Here, for instance, is a regular language
#
#     $$ \{ a^i b^j c^k \;:\; i,j,k \ge 0 \}$$
#
#
# **Task for you**:
#
# * Define the above set in Python, limiting $i,j,k$ to be in $\{0, \ldots, 4\}$.
#
# **IMPORTANT NOTE**: ALL finite sets are regular. Thus by truncating the set to a finite size, we always get a regular language. The purpose of truncation is ONLY to make sure that the printing stops. What we are really referring to as a regular language of interest is the mathematical language
#
#    $$ \{ a^i b^j c^k \;:\; i,j,k \ge 0 \}$$
#
#
# </font>

# %%
import random
# The above regular language truncated to a small size, below
# https://www.youtube.com/watch?v=vQg-S6tKfqE&feature=youtu.be
A_reg_Language = {x+y+z for x in ('', 'a', 'aa', 'aaa', 'aaaa') for y in ('', 'b', 'bb', 'bbb', 'bbbb') for z in ('', 'c', 'cc', 'ccc', 'cccc')}

# Print its contents
print(A_reg_Language)
print(len(A_reg_Language))
# Out:
# {'', 'abbbbcc', 'abb', 'bbcccc', 'bbc', 'aaaabbbc', 'aaaabbbcc', 'aaaccc', 'aaaabbbbccc', 'aabbbbcccc', 'ac', 'aaabb', 'aaaa', 'bccc', 'b', 'aabbbbcc', 'bbbb', 'aaaabbc', 'aaaabbbbcccc', 'aaaabbbbcc', 'abc', 'bbccc', 'aaaaccc', 'cccc', 'bbcc', 'aabbccc', 'aaaacc', 'c', 'aaabbbcccc', 'abcccc', 'aabbc', 'acc', 'aabbbcccc', 'abbc', 'aabbbc', 'bbbbcccc', 'aaaab', 'bcc', 'aaabbb', 'bbbccc', 'aaabbbb', 'aaabbbbc', 'aaab', 'aabbbbc', 'aaaabbcc', 'aaaabc', 'aaabbbc', 'bbb', 'bc', 'aabbbbccc', 'cc', 'aaabbbbccc', 'aabb', 'aaabcc', 'aaacccc', 'aaaacccc', 'aaabcccc', 'aabbcc', 'aaaabbb', 'aabbb', 'abbbbc', 'aaaabbcccc', 'aaaabbbb', 'acccc', 'abbbcccc', 'bbbbcc', 'abccc', 'aaccc', 'ab', 'aaabbcc', 'aabc', 'aabcccc', 'aabbcccc', 'aaaabbccc', 'bbbcccc', 'abbbbcccc', 'aaabccc', 'aab', 'aaabbcccc', 'aaabbbcc', 'aabcc', 'aaabbccc', 'aacccc', 'aaabbbccc', 'bbbbccc', 'aaaabb', 'abbcccc', 'aaaac', 'aaabc', 'accc', 'aabbbccc', 'bcccc', 'aaacc', 'aaac', 'aabbbb', 'aaaabbbbc', 'abbcc', 'aa', 'bb', 'a', 'abbbbccc', 'aacc', 'aac', 'aabccc', 'aaabbbbcccc', 'abbbccc', 'abbbb', 'aaabbc', 'bbbc', 'abcc', 'aaaabcccc', 'aaaabccc', 'aaaabbbccc', 'aaabbbbcc', 'abbb', 'abbccc', 'bbbbc', 'ccc', 'abbbc', 'aaaabbbcccc', 'aaaabcc', 'abbbcc', 'aaa', 'bbbcc', 'aabbbcc'}
# 125

# %% [markdown]
# ## Define a context-free language via Python's set builder (set comprehension) syntax
#
# <font size="4">
#
# Recall from Chapter-1 that sets of strings of the form "any number of $a$'s followed by the same number of $b$'s and $c$'s is context-free.
#
# * Here, for instance, is a context-free language
#
#     $$ \{ a^i b^j c^j \;:\; i,j \ge 0 \}$$
#
#
# **Task for you**:
#
# * Define the above set in Python, again limiting $i,j,k$ to be in $\{0, \ldots, 4\}$.
#
# **IMPORTANT NOTE**: ALL finite sets are regular. Thus by truncating the set to a finite size, we always get a regular language. The purpose of truncation is ONLY to make sure that the printing stops. What we are really referring to as a **context-free language** of interest is the mathematical language
#
#    $$ \{ a^i b^j c^j \;:\; i,j \ge 0 \}$$
#
#
# </font>

# %%
import random
# Your Python definition of a context-free language, below
# https://www.youtube.com/watch?v=vQg-S6tKfqE&feature=youtu.be
A_reg_Language = {x+y+z for x in ('', 'a', 'aa', 'aaa', 'aaaa') for y in ('', 'b', 'bb', 'bbb', 'bbbb') for z in ('', 'c', 'cc', 'ccc', 'cccc') if len(y) == len(z)}

# Print its contents
print(A_reg_Language)
print(len(A_reg_Language))
# Out:
# {'', 'abc', 'aabbcc', 'a', 'bbcc', 'aaabbcc', 'aabc', 'aaabbbbcccc', 'abbbccc', 'abbbbcccc', 'aabbbbcccc', 'bbbbcccc', 'aaaa', 'aaabbbccc', 'bbbccc', 'aaaabbbccc', 'aaabc', 'aaaabbcc', 'aabbbccc', 'aaaabc', 'aaaabbbbcccc', 'bc', 'aaa', 'abbcc', 'aa'}
# 25

# %% [markdown]
# ## Define another context-free language
#
# <font size="4">
#
# In Chapter 4, we will study the Pumping Lemma to argue that this language is not context-free:
#     $$L_{if} = \{ a^i b^j c^k \;:\; {\rm if}\; (i=2)\; {\rm then}\; (j=k) \}$$
#
#
#
# **Task for you**:
#
# * Define $L_{if}$ in Python, again limiting $i,j,k$ to be in $\{0, \ldots, 4\}$.
# * List all the strings where the condition $(i=2)$ is met. How many such strings are there?
#
# **IMPORTANT NOTE**: ALL finite sets are regular. Thus by truncating the set to a finite size, we always get a regular language. The purpose of truncation is ONLY to make sure that the printing stops. What we are really referring to as a **context-free language** of interest is the mathematical language
#
#
#   $$L_{if} = \{ a^i b^j c^k \;:\; {\rm if}\; (i=2)\; {\rm then}\; (j=k) \}$$
#
#
# </font>

# %%
 
# Your Python definition of the language Lif below
# https://www.youtube.com/watch?v=vQg-S6tKfqE&feature=youtu.be
Lif = {i+j+k for i in ('', 'a', 'aa', 'aaa', 'aaaa') for j in ('', 'b', 'bb', 'bbb', 'bbbb') for k in ('', 'c', 'cc', 'ccc', 'cccc') if len(i)==2 and len(j)==len(k)}

# print Lif

print(Lif)
print(len(Lif))
# Out:
# {'aabbbccc', 'aabbcc', 'aabbbbcccc', 'aabc', 'aa'}
# 5

# %%
# Your Python definition of the language Lif below
# https://www.youtube.com/watch?v=vQg-S6tKfqE&feature=youtu.be
Lif = {i+j+k for i in ('', 'a', 'aa', 'aaa', 'aaaa') for j in ('', 'b', 'bb', 'bbb', 'bbbb') for k in ('', 'c', 'cc', 'ccc', 'cccc') if (len(i)==2 and len(j)==len(k)) or len(i) != 2}

# print Lif

print(Lif)
print(len(Lif))
# Out:
# {'', 'bcc', 'aaabbbbcc', 'bbcc', 'aaaabcccc', 'aaaabbccc', 'aaabbbbc', 'aaaabbb', 'ab', 'aaabcc', 'aaabbb', 'abbbc', 'bbbbcc', 'abbc', 'bcccc', 'bbbcccc', 'bbbbcccc', 'aaaabb', 'aaaccc', 'aaaab', 'aaaabbbcccc', 'aaabbcc', 'aaabbbc', 'aaabbbcccc', 'aaabb', 'aaaabbbbccc', 'aaabbbcc', 'aaaabbc', 'bbbb', 'acc', 'aaabcccc', 'aa', 'aaaa', 'aaaabbbcc', 'abc', 'aabbcc', 'aaaabccc', 'abbb', 'aaaabbcccc', 'ccc', 'abcc', 'abbcccc', 'aaabbccc', 'aaaabbbb', 'bbbbc', 'abccc', 'abbbccc', 'abbbbcccc', 'bbcccc', 'aaaabbbbcc', 'c', 'bbc', 'aaa', 'abbbbcc', 'abbccc', 'aaaabcc', 'bbb', 'bbbc', 'aaaacccc', 'bbccc', 'aaaacc', 'aabc', 'aaaabbbccc', 'aaaabbbc', 'aaaabc', 'bc', 'aabbbbcccc', 'cc', 'a', 'abbbb', 'abbcc', 'abb', 'aaab', 'abcccc', 'aaabbbccc', 'abbbbccc', 'aaacc', 'aaaabbbbc', 'aaaabbbbcccc', 'accc', 'aaac', 'aabbbccc', 'bbbbccc', 'acccc', 'aaabbbbcccc', 'bccc', 'aaabbcccc', 'bbbcc', 'aaaabbcc', 'aaabccc', 'aaabc', 'b', 'abbbbc', 'abbbcc', 'aaabbbb', 'aaaac', 'aaacccc', 'aaaaccc', 'bb', 'cccc', 'aaabbc', 'aaabbbbccc', 'abbbcccc', 'bbbccc', 'ac'}
# 105

# %% [markdown]
# # Number of strings where (i=2) is met, and which are they?
#
# There are 35 strings where (i=2) is met. 25 in the regular language, 5 in the first context-free language, and 5 in the second context-free language.
#
# # The strings where i = 2 is met are these:
#
# In the regular language:
#
# 'aabbbbcccc', 'aabbbbcc', 'aabbccc', 'aabbc', 'aabbbcccc', 'aabbbc', 'aabbbbc', 'aabbbbccc', 'aabb', 'aabbcc', 'aabbb', 'aaccc', 'aabc', 'aabcccc', 'aabbcccc', 'aab', 'aabcc', 'aacccc', 'aabbbccc', 'aabbbb', 'aa', 'aacc', 'aac', 'aabccc' 'aabbbcc'
#
# <br>
#
# In the first context-free language:
#
# 'aabbcc', 'aabc', 'aabbbbcccc', 'aabbbccc', 'aa'
#
# <br>
#
# In the second context-free language:
#
# 'aabbbccc', 'aabbcc', 'aabbbbcccc', 'aabc', 'aa'

# %% [markdown]
# <br>
# <br>
#
# # Caleb Fullmer's Comments:
#
# This assignment was fairly simple after looking at this description of Python’s set builder notation. https://www.youtube.com/watch?v=vQg-S6tKfqE&feature=youtu.be. Clara Chan and Matthew Loumeau also gave a lot of help, specifically on the second context-free language.

# %% [markdown]
# # END

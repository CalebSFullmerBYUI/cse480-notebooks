# %% [markdown]
# # First let's import, then look for the assignment below

# %%
#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
import sys

# -- Detect if in Own Install or in Colab
try:
    import google.colab
    OWN_INSTALL = False
except:
    OWN_INSTALL = True
    
if OWN_INSTALL:

  sys.path[0:0] = ['../../../../..',  '../../../../../3rdparty',  
                   '../../../..',  '../../../../3rdparty',  
                   '../../..',     '../../../3rdparty', 
                   '../..',        '../../3rdparty',
                   '..',           '../3rdparty' ]

else: # In colab
  ! if [ ! -d Jove ]; then git clone https://github.com/ganeshutah/Jove Jove; fi
  sys.path.append('./Jove')
  sys.path.append('./Jove/jove')

# -- common imports --
from jove.LangDef   import *
#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Out:
# Cloning into 'Jove'...
# remote: Enumerating objects: 4634, done.
# remote: Total 4634 (delta 0), reused 0 (delta 0), pack-reused 4634
# Receiving objects: 100% (4634/4634), 7.38 MiB | 22.48 MiB/s, done.
# Resolving deltas: 100% (3005/3005), done.
# You may use any of these help commands:
# help(lphi)
# help(lunit)
# help(lcat)
# help(lexp)
# help(lunion)
# help(lstar)
# help(srev)
# help(lrev)
# help(shomo)
# help(lhomo)
# help(powset)
# help(lint)
# help(lsymdiff)
# help(lminus)
# help(lissubset)
# help(lissuperset)
# help(lcomplem)
# help(product)
# help(nthnumeric)

# %% [markdown]
# # Week 02 Notebook 4 on DeMorgan's Law
#
# <font size="4">
#
# Let's illustrate DeMorgan's Law using Jove.
#
# </font>

# %% [markdown]
# # Define the universe $\Sigma_4^*$ for the $\Sigma$ given below, consulting Pages 28-29 of our book

# %%
Sigma = {'a', 'b', 'c'}

Sigma_4_Star = lstar(Sigma, 4)
print(Sigma_4_Star)
# Out:
# {'', 'ccba', 'cbaa', 'ccac', 'bccb', 'acb', 'cccb', 'aaca', 'cbbc', 'cbbb', 'ccaa', 'aabc', 'baca', 'aca', 'bcac', 'bccc', 'bab', 'bac', 'ac', 'acbb', 'aa', 'ccbb', 'bbca', 'bcbc', 'caca', 'cbcc', 'cbac', 'accc', 'bbbc', 'acac', 'caac', 'aaaa', 'acca', 'abac', 'cccc', 'bbab', 'abaa', 'accb', 'baac', 'bcba', 'cabb', 'bacc', 'babb', 'acc', 'aabb', 'aaac', 'abbc', 'cab', 'aaba', 'bacb', 'abc', 'caba', 'bbaa', 'ccab', 'cba', 'ccb', 'ccc', 'bcb', 'cacb', 'aaab', 'bcab', 'bba', 'bb', 'ccbc', 'bca', 'aacb', 'cacc', 'bbac', 'aaa', 'bbcc', 'cbcb', 'cbba', 'bbbb', 'acbc', 'ba', 'bcbb', 'bcaa', 'abab', 'cbab', 'cabc', 'bbcb', 'cbc', 'ab', 'baa', 'abbb', 'bbb', 'abb', 'baaa', 'babc', 'ccca', 'aac', 'bc', 'cb', 'a', 'acba', 'aab', 'baab', 'cbb', 'abca', 'baba', 'abcc', 'cac', 'bbc', 'ca', 'bbba', 'cc', 'bcc', 'cbca', 'c', 'caaa', 'bcca', 'aba', 'acab', 'b', 'caab', 'abcb', 'cca', 'abba', 'caa', 'acaa', 'aacc'}

# %% [markdown]
# # Illustrate DeMorgan's law with respect to these two sets:
#
# * $A = \{a, \varepsilon , bc\}$
#
# * $B = \{a, \varepsilon, bba, ca\}$
#
# ## Specific instructions
#
# * Show, using Jove, that $\overline{(A\cup B)} = \overline{A} \cap \overline{B}$.
#
# * Here, LHS = $\overline{(A\cup B)}$
#
# * And RHS = $\overline{A} \cap \overline{B}$

# %%
A = {'a', '', 'bc'}
B = {'a', '', 'bba', 'ca'}

print((Sigma_4_Star - (A|B)) == (((Sigma_4_Star - A) - ((Sigma_4_Star - A) - (Sigma_4_Star - B))) | ((Sigma_4_Star - B) - ((Sigma_4_Star - B) - (Sigma_4_Star - A)))))
# Out:
# True

# %%
help(lcomplem) # read and follow
# Out:
# Help on function lcomplem in module jove.LangDef:
#
# lcomplem(L, sigma, n)
#     In : L (language : set of strings)
#          sigma (alphabet : set of strings)
#          n (finite limit for lstar : int)
#     Out : sigma*_n - L (language : set of strings)
#     Example:
#     L = {'0', '10', '010'}
#     sigma = {'0', '1'}
#     n = 3
#     lcomplem(L4,{'0','1'}, 3) ->
#     {'', '000', '101', '011', '00', '1',
#      '001', '110', '111', '100', '01', '11'}

# %%
help(lunion) # read and follow
# Out:
# Help on function lunion in module jove.LangDef:
#
# lunion(L1, L2)
#     In : L1 (language : a set),
#          L2 (language : a set).
#     Out: L1 union L2 (language : a set).

# %%
help(lint) # read and follow
# Out:
# Help on function lint in module jove.LangDef:
#
# lint(L1, L2)
#     In : L1 (language : set of strings)
#          L2 (language : set of strings)
#     Out: L1 intersection L2 (sets of strings)

# %% [markdown]
# # OK, we are all set!

# %%
A = {'a', '' , 'bc'}

B = {'a', '', 'bba', 'c'}

# %%
LHS = lcomplem(lunion(A, B), Sigma, 4)

RHS = lint(lcomplem(A, Sigma, 4), lcomplem(B, Sigma, 4))

# %% [markdown]
# # Check DeMorgan's Law

# %%
# Now, perform LHS == RHS in Python and check if it is true

LHS == RHS

# Must print True
# Out:
# True

# %% [markdown]
# # END
